# %% [markdown]
# # Regresja liniowa
#
# Naszym Celem jest empityczne sprawdzenie twierdzenia:
#
# Niech $A \in \mathbb{R}^{N\times K}$ będzie macierzą która przekształca $\mathbb{R}^{K}$ w $\mathbb{R}^N$, i niech $y \in \mathbb{R}^{K}$.
#
# Wtedy punkt $x_0 \in \mathbb{R}^K$ spełnia
#
# $$
# x_0 = \mathrm{argmin} \{ x \in \mathbb{R}^K   \colon \| Ax - y \|^2 \}
# $$
#
# wtedy i tylko wtedy gdy
#
# $$
# A^TA x_0 = A^Ty.
# $$

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę wykres funkcji w kształcie
#
# $
# f(x)=x^2
# $
#
# na odcinku $[0,3]$ i go narysować.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: (x**2)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %%
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)=x^2$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y);
print(lr.coef_)
print(lr.intercept_)
# Out:
# [3.42671028]
# -2.1637263358586525

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr = lambda x: lr.coef_ * x +lr.intercept_

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Teraz możemy wykonać predykcję dla punktu
# $$
# x_0 = 1.5
# $$

# %%
point = np.array([1.5])
y_point = lr.predict(point[:, np.newaxis])

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.plot(point, y_point, 'or', ms=10);
plt.show()

# %% [markdown]
# Możemy wypisać miarę dopasowania $R^2$. Narazie nie wnikamy w to co ona oznacza.

# %%
from sklearn.metrics import r2_score
print(lr.score(x[:, np.newaxis], y))
print(r2_score(lr.predict(x[:, np.newaxis]), y))
# Out:
# 0.876852776839565
# 0.8595576972404719

# %% [markdown]
# # Zadanie 1
# Stwórz macierz postaci:
# $$
# A=\begin{bmatrix}
# x_1 & 1\\
# \ddots & \ddots\\
# x_n & 1\\
# \end{bmatrix}
# $$
#
# i rozwiąż równanie
#
# $$
# A^TA x = A^Ty.
# $$
#
# gdzie (x,y) to nasz zbiór treningowy.
#
# Użyj funkcji <tt>linalg.solve</tt>.

# %%
deg=1
xx=np.vander(x, deg + 1)
xx
# Out:
# array([[0.2, 1. ],
#        [0.5, 1. ],
#        [0.8, 1. ],
#        [0.9, 1. ],
#        [1.3, 1. ],
#        [1.7, 1. ],
#        [2.1, 1. ],
#        [2.7, 1. ]])

# %%
w = np.linalg.solve(np.dot(xx.T,xx), np.dot(xx.T,y))
w
# Out:
# array([ 3.42671028, -2.16372634])

# %% [markdown]
# # Zadanie 2
# Zapoznaj się z funkcją <tt>optimize.fmin_cg</tt>
# https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.optimize.fmin_cg.html
# i znajdż minum funkcji
#
# $$
# f(x,y) = (x+1)^2+y^2
# $$

# %%
from scipy import optimize
def f(x): 
    x1,y = x
    return (x1+1)**2 + y**2
x0 = np.asarray((0,0))
a,b = optimize.fmin_cg(f,x0)
print(a)
print(b)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 16
#          Gradient evaluations: 4
# -1.0000000073028306
# -7.4505805958230046e-09

# %% [markdown]
# # Zadanie 3
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error}(a,b;(x,y)) =  \sum_{i=1}^{n} ( y_i - (ax_i+b) )^2.
# $$

# %% [markdown]
# # Zadanie 4
# Zminimalizuj funkcją $\mathrm{compute\_error}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
Initial = lambda x: (x**2)
x_initial = np.linspace(0., 3, 200)
y_initial = Initial(x_tr)

# %%
x_population = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y_population = Initial(x) + np.random.randn(len(x))

# %%
def compute_error(w):
    a,b = w
    return np.sum(np.power(y_population-(a*x_population+b),2))

# %%
guess = np.asarray((0,0))
compute_error(guess)
# Out:
# 94.25455718182191

# %%
x0 = np.asarray((0,0))
min_a, min_b = optimize.fmin_cg(compute_error,x0)
print("\n\n REGRESSION: \n\n y = %s * x + %s" % (min_a,min_b))
# Out:
# Optimization terminated successfully.
#          Current function value: 10.879805
#          Iterations: 3
#          Function evaluations: 24
#          Gradient evaluations: 6
#
#
#  REGRESSION:
#
#  y = 3.517989705130287 * x + -2.8534194355940716

# %%
f = lambda x: (x*abs_a) + abs_b
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k', color='r');
plt.plot(x_initial, y_initial, '--k');

plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie 5
# Zdafiniuj funkcję opisującą błąd kwadratowy:
#
# $$
# \mathrm{compute\_error\_1}(a,b;(x,y)) =  \sum_{i=1}^{n} |y_i - (ax_i+b)|.
# $$

# %% [markdown]
# # Zadanie 6
# Zminimalizuj funkcją $\mathrm{compute\_error\_1}$ po parametrach $a,b$ (numerycznie).
#
# Czy wyniki są podobne do wyników z poprzednich zadań?

# %%
Initial = lambda x: (x**2)
x_initial = np.linspace(0., 3, 200)
y_initial = Initial(x_tr)

# %%
x_population = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y_population = Initial(x) + np.random.randn(len(x))

# %%
def compute_error_1(w):
    a,b = w
    return np.sum(np.abs(y-(a*x+b)))

# %%
guess = np.asarray((0,0))
compute_error(guess)
# Out:
# 102.21049330393801

# %%
x0 = np.asarray((0,0))
min_a, min_b = optimize.fmin_cg(compute_error,x0)
print("\n\n REGRESSION: \n\n y = %s * x + %s" % (min_a,min_b))
# Out:
# Optimization terminated successfully.
#          Current function value: 12.998860
#          Iterations: 2
#          Function evaluations: 20
#          Gradient evaluations: 5
#
#
#  REGRESSION:
#
#  y = 3.233858748548313 * x + -1.9794125759509895

# %%
f = lambda x: (x*abs_a) + abs_b
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k', color='r');
plt.plot(x_initial, y_initial, '--k');

plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie 7
# Wykonaj dwie powyższe regresję na danych z wartością odstającą.

# %%
f = lambda x: (x)
x_tr = np.linspace(0., 3, 200)
y_tr = f(x_tr)
x = np.array([.2, .5, .8, .9, 1.3, 1.7, 2.1, 2.7])
y = f(x) + np.random.randn(len(x))/5
y[1]=y[1]+10
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,12])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %%
points = np.column_stack((x,y))
